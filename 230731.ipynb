# %% [markdown]
# ## 알고리즘
# 문제를 해결하기 위한 절차나 방법
#
# ### 좋은 알고리즘이란?
# 1. 정확성
# 2. 작업량
# 3. 메모리사용량
# 4. 단순성
# 5. 최적성

# %% [markdown]
# ## Time Complexity    , 빅오표기법과 비슷하게 쓰임
#     - 실제 걸리는 시간을 추정
#     - 실행되는 명령문의 개수를 계산

# %% [markdown]
# ## 배열
#     일정한 자료형의 변수들을 하나의 이름으로 열거하여 사용하는 자료구조
#
#
# ### 배열의 필요성
#     1. 프로그램 내에서 여러 개의 변수가 필요할 때, 일일이 변수명을 이용하여 자료에 접근하는 것은 매우 비효율적일 수 있다.
#
#     2. 배열을 사용하면 하나의 선언을 통해 둘 이상의 변수를 선언할 수 있다.
#
#     3. 단순히 다수의 변수 선언을 의미하는 것이 아니라, 다수의 변수로는 하기 힘든 작업을 배열을 활용해 쉽게 할 수 있다.

# %% [markdown]
# ## 정렬
#     2개 이상 자료를 특정 기준에 의해 오름차순, 내림차순으로 재배열 하는 것
#
#
# ## 대표적인 정렬 방식의 종류
# 1. 버블
# 2. 카운팅
# 3. 선택
# 4. 퀵
# 5. 삽입
# 6. 정렬

# %% [markdown]
# ## 버블 정렬
#     인접한 두 개의 원소를 비교하며 자리를 게속 교환하는 방식
#
# ### 정렬 과정
# 1. 첫 번째 원소부터 인접한 원소끼리 계속 자리를 교환하면서 맨 마지막 자리까지 이동한다
# 2. 한 단계가 끝나면 가장 큰 원소가 마지막 자리로 정렬된다.
# *시간복잡도  O(n^2)
#
# ## 카운팅 정렬
#     항목들의 순서를 결정하기 위해 집합에 각 항목이 몇 개씩 있는지 세는 작업을 하여,
#     선형시간에 정렬하는 효율적인 알고리즘
#
# ### 카운팅 정렬 과정
# 1. DATA에서 각 항목의 발생 회수를 세고, 정수 항목들로 직접 인덱스 되는 카운트 배열 counts에 저장한다.
# 2. 정렬된 집합에서 각 항목의 앞에 위치할 항목의 개수를 반영하기 위해 counts의 원소를 조정한다.
#
# ### 제한사항
# 1. 정수나 정수로 표현할 수 있는 자료에 대해서만 적용 가능
# 2.
# *시간복잡도

# %% [markdown]
# ## 완전 검색
# 문제의 해법으로 생각할 수 있는 ㅂ모든 경우의 수를 냐열해보고 확인하는 기법이다.

# %% [markdown]
# ## 그리디
# ### 동작과정
# 1. 해선택
# 2. 실행가능성검사
# 3. 해검사
