# %% [markdown]
# ## 트리
# - 사이클이 없는 연결그래프
#     사이클: 시작지점에서 출발하여 각 간선을 한번만 거치고 다시 출발점 복귀 가능한 구조(한붓그리기 가능한 구조)
#     연결그래프: 모든 꼭지점에서 갈 수 있다.
#
# ## 이진트리
#     자녀노드가 둘 이하인 트리
#     -핵심
#     0. 이진트리의 종류
#         1. 포화 이진트리
#         - 모든 레벨이 꽉 차있는 것
#         2. 완전 이진 트리
#         -마지막레벨을 제외한 모든 레벨은 꽉 차있어야 한다.
#         - 마지막 레벨 노드는 왼쪽부터 채워져야 한다.
#         3. 나머진 이진 트리
#     1. 순회 방법
#     2. 트리 저장 방법
#
# ### 순회
#
#     1. 전위 ( 부모 좌 우)
#     2. 중위 ( 좌 부모 우)
#     3. 후위 ( 좌 우 부모)
#
# ### 트리 저장 방법
# arr = [1, 2, 1, 3, 2, 4, 3, 5, 3, 6]
#     1. 일차원 배열 저장
#         (N*2+1) 왼쪽
#         (N*2+2) 오른쪽
#         [1, 2, 3, 4, 0 ,5, 6]
#
#     2. 연결리스트 저장 - 개발용
#
#
# ### 삭제
#
#
#     2. 삭제할 노드가 리프 노드가 아닌 경우: 차수가 2인 경우
#         왼쪽 서브트리의 가장 오른쪽 자식 노드 vs 오른쪽 서브 트리의 가장 왼쪽 자식
